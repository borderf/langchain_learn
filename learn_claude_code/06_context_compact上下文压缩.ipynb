# %% [markdown]
# ### 1. 问题
# agent现在已经学会了读写文件、规划步骤、派生子agent、按需加载skill。
# 它会做的事情越来越多，上下文就会越来越快膨胀。
# 如果没有上下文压缩，很快会出现问题：
# 1、模型注意力被旧知识淹没
# 2、API耗费的token越来越多，成本越来越高
# 3、最后会触及模型的上下文上限，任务中断
# 要解决的主要问题：怎样在不丢失主线连续性的情况下，把活跃的上下文腾出空间。
# ### 2.相关名词
# #### 2.1. 上下文窗口
# 模型这一轮真正能一起看到的输入容量，它不是无限的。
# #### 2.2. 什么是活跃上下文
