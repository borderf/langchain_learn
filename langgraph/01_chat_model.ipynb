# %% [markdown]
# ### 1.设置环境变量
# 通过环境变量设置API KEY, Base URL

# %%
import getpass
import os
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass.getpass("输入你的API Key: ")
if not os.environ.get("OPENAI_BASE_URL"):
    os.environ["OPENAI_BASE_URL"] = getpass.getpass("输入你的Base URL: ")

# %% [markdown]
# ### 2.初始化ChatModel
# 使用ChatModel的子类进行初始化，此处使用openai

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="Qwen/Qwen3-8B",
    temperature=0.1,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %% [markdown]
# 使用init_chat_model初始化ChatModel

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(
    model="Qwen/Qwen3-8B",
    model_provider="openai",
    temperature=0.1,
    max_tokens=2000,
    timeout=None,
    max_retries=3,
    base_url="https://api.siliconflow.cn/v1",
)

# %% [markdown]
# 测试一下llm

# %%
llm.invoke("你好，你是谁")
# Out:
# AIMessage(content='你好！我是通义千问，是通义实验室开发的超大规模语言模型。我能够回答各种问题、创作文字，比如写故事、写邮件、写剧本，还能进行逻辑推理、多语言翻译，甚至编写代码。我的目标是让每个人都能更高效地获取信息、创造内容和解决问题。有什么我可以帮你的吗？', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 16, 'total_tokens': 90, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'Qwen/Qwen3-8B', 'system_fingerprint': '', 'id': '019c4bbced2b3330698b2db469b5fb80', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c4bbc-ee8e-77e0-9e9a-ecb54d078962-0', usage_metadata={'input_tokens': 16, 'output_tokens': 74, 'total_tokens': 90, 'input_token_details': {}, 'output_token_details': {'reasoning': 0}})

# %% [markdown]
# 测试一下model

# %%
model.invoke("你好，你是谁")
# Out:
# AIMessage(content='你好！我是通义千问，是通义实验室推出的超大规模语言模型。我能够帮助你回答问题、创作文字，比如写故事、写邮件、写剧本等，还能进行多轮对话，保持上下文连贯。此外，我还能回答各种领域的问题，包括但不限于科技、文化、生活等。如果你有任何问题或需要帮助，欢迎随时告诉我！', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 80, 'prompt_tokens': 16, 'total_tokens': 96, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'Qwen/Qwen3-8B', 'system_fingerprint': '', 'id': '019c4bbd6fceaf17c4d9af214ab3a7d3', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c4bbd-7182-7db1-80b5-fbf5f56cde81-0', usage_metadata={'input_tokens': 16, 'output_tokens': 80, 'total_tokens': 96, 'input_token_details': {}, 'output_token_details': {'reasoning': 0}})
